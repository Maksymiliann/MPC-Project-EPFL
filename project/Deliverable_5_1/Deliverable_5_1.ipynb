# %%
# %load_ext autoreload
# %autoreload 2

# Get parent directory and add to sys.path
import os; import sys
import numpy as np
parent_dir = os.path.dirname(os.getcwd())
sys.path.append(parent_dir)

# Require ipympl
# %matplotlib widget

# %%
# MPC import
from Deliverable_5_1.LinearMPC.MPCVelControl import MPCVelControl
from PIControl.PIControl import PIControl

from src.rocket import Rocket
from src.vel_rocket_vis import RocketVis, plot_static_states_inputs

rocket_obj_path = os.path.join(parent_dir, "Cartoon_rocket.obj")
rocket_params_path = os.path.join(parent_dir, "rocket.yaml")

# %%
Ts = 0.05
sim_time = 15; H = 5.0
x0 = np.array([0, 0, 0, 0, 0, 0, 5, 5, 10, 0, 0, 1])  # initial state
x_target = np.zeros((12,))

rocket = Rocket(Ts=Ts, model_params_filepath=rocket_params_path)
mpc = MPCVelControl().new_controller(rocket, Ts, H)

# Static mass change and zero fuel rate
rocket.mass = 1.5
rocket.fuel_rate = 0.0
t_cl, x_cl, u_cl, t_ol, x_ol, u_ol, ref = rocket.simulate_control(mpc, sim_time, H, x0, x_target=x_target, method='nonlinear')

vis = RocketVis(rocket, rocket_obj_path)
vis.anim_rate = 1.0
vis.animate(t_cl[:-1], x_cl[:,:-1], u_cl, Ref=ref[:,:-1], T_ol=t_ol[...,:-1], X_ol=x_ol, U_ol=u_ol);
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Simulating time 0.00:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  10.0000
#   vz_trim        =  0.0000
#   dx_meas        =  10.0000
# [observer]
#   dx_hat (est)   =  10.0000
#   d_hat  (est)   =  0.0000
#   du_prev        =  0.0000
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -0.0000
# [mpc initial condition]
#   dX0            =  10.0000
# [mpc output]
#   du_cmd         = -26.5667
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.05:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.8777
#   vz_trim        =  0.0000
#   dx_meas        =  9.8777
# [observer]
#   dx_hat (est)   =  9.7557
#   d_hat  (est)   = -0.0734
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) =  0.4987
# [mpc initial condition]
#   dX0            =  9.7557
# [mpc output]
#   du_cmd         = -27.0654
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.10:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.7601
#   vz_trim        =  0.0000
#   dx_meas        =  9.7601
# [observer]
#   dx_hat (est)   =  9.5584
#   d_hat  (est)   = -0.0707
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) =  0.4809
# [mpc initial condition]
#   dX0            =  9.5584
# [mpc output]
#   du_cmd         = -27.0476
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.15:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.6617
#   vz_trim        =  0.0000
#   dx_meas        =  9.6617
# [observer]
#   dx_hat (est)   =  9.4008
#   d_hat  (est)   = -0.0088
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) =  0.0596
# [mpc initial condition]
#   dX0            =  9.4008
# [mpc output]
#   du_cmd         = -26.6263
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.20:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.5305
#   vz_trim        =  0.0000
#   dx_meas        =  9.5305
# [observer]
#   dx_hat (est)   =  9.2569
#   d_hat  (est)   =  0.0691
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -0.4695
# [mpc initial condition]
#   dX0            =  9.2569
# [mpc output]
#   du_cmd         = -26.0972
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.25:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.3601
#   vz_trim        =  0.0000
#   dx_meas        =  9.3601
# [observer]
#   dx_hat (est)   =  9.1062
#   d_hat  (est)   =  0.1310
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -0.8907
# [mpc initial condition]
#   dX0            =  9.1062
# [mpc output]
#   du_cmd         = -25.6759
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
#  State beta violation: -0.19 < -0.17,
#  State alpha violation: 0.20 > 0.17,
# Simulating time 0.30:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.1825
#   vz_trim        =  0.0000
#   dx_meas        =  9.1825
# [observer]
#   dx_hat (est)   =  8.9479
#   d_hat  (est)   =  0.1768
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -1.2019
# [mpc initial condition]
#   dX0            =  8.9479
# [mpc output]
#   du_cmd         = -25.3647
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
#  State beta violation: -0.20 < -0.17,
#  State alpha violation: 0.21 > 0.17,
# Simulating time 0.35:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.0084
#   vz_trim        =  0.0000
#   dx_meas        =  9.0084
# [observer]
#   dx_hat (est)   =  8.7856
#   d_hat  (est)   =  0.2131
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -1.4487
# [mpc initial condition]
#   dX0            =  8.7856
# [mpc output]
#   du_cmd         = -25.1180
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
#  State beta violation: -0.19 < -0.17,
#  State alpha violation: 0.19 > 0.17,
# Simulating time 0.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.9081
#   vz_trim        =  0.0000
#   dx_meas        =  8.9081
# [observer]
#   dx_hat (est)   =  8.6498
#   d_hat  (est)   =  0.2866
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -1.9485
# [mpc initial condition]
#   dX0            =  8.6498
# [mpc output]
#   du_cmd         = -24.6182
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.8104
#   vz_trim        =  0.0000
#   dx_meas        =  8.8104
# [observer]
#   dx_hat (est)   =  8.5330
#   d_hat  (est)   =  0.3829
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -2.6033
# [mpc initial condition]
#   dX0            =  8.5330
# [mpc output]
#   du_cmd         = -23.9634
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.7091
#   vz_trim        =  0.0000
#   dx_meas        =  8.7091
# [observer]
#   dx_hat (est)   =  8.4272
#   d_hat  (est)   =  0.4886
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -3.3215
# [mpc initial condition]
#   dX0            =  8.4272
# [mpc output]
#   du_cmd         = -23.2452
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.5984
#   vz_trim        =  0.0000
#   dx_meas        =  8.5984
# [observer]
#   dx_hat (est)   =  8.3247
#   d_hat  (est)   =  0.5913
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -4.0198
# [mpc initial condition]
#   dX0            =  8.3247
# [mpc output]
#   du_cmd         = -22.5468
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.4813
#   vz_trim        =  0.0000
#   dx_meas        =  8.4813
# [observer]
#   dx_hat (est)   =  8.2215
#   d_hat  (est)   =  0.6853
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -4.6588
# [mpc initial condition]
#   dX0            =  8.2215
# [mpc output]
#   du_cmd         = -21.9079
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
#  State alpha violation: 0.17 > 0.17,
# Simulating time 0.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.3690
#   vz_trim        =  0.0000
#   dx_meas        =  8.3690
# [observer]
#   dx_hat (est)   =  8.1194
#   d_hat  (est)   =  0.7737
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -5.2601
# [mpc initial condition]
#   dX0            =  8.1194
# [mpc output]
#   du_cmd         = -21.3066
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.2624
#   vz_trim        =  0.0000
#   dx_meas        =  8.2624
# [observer]
#   dx_hat (est)   =  8.0199
#   d_hat  (est)   =  0.8595
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -5.8436
# [mpc initial condition]
#   dX0            =  8.0199
# [mpc output]
#   du_cmd         = -20.7231
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.1551
#   vz_trim        =  0.0000
#   dx_meas        =  8.1551
# [observer]
#   dx_hat (est)   =  7.9216
#   d_hat  (est)   =  0.9406
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -6.3950
# [mpc initial condition]
#   dX0            =  7.9216
# [mpc output]
#   du_cmd         = -20.1716
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.80:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.0466
#   vz_trim        =  0.0000
#   dx_meas        =  8.0466
# [observer]
#   dx_hat (est)   =  7.8232
#   d_hat  (est)   =  1.0157
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -6.9051
# [mpc initial condition]
#   dX0            =  7.8232
# [mpc output]
#   du_cmd         = -19.6616
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.85:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.9370
#   vz_trim        =  0.0000
#   dx_meas        =  7.9370
# [observer]
#   dx_hat (est)   =  7.7241
#   d_hat  (est)   =  1.0839
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -7.3692
# [mpc initial condition]
#   dX0            =  7.7241
# [mpc output]
#   du_cmd         = -19.1975
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.90:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.8280
#   vz_trim        =  0.0000
#   dx_meas        =  7.8280
# [observer]
#   dx_hat (est)   =  7.6245
#   d_hat  (est)   =  1.1462
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -7.7927
# [mpc initial condition]
#   dX0            =  7.6245
# [mpc output]
#   du_cmd         = -18.7740
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.95:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.7195
#   vz_trim        =  0.0000
#   dx_meas        =  7.7195
# [observer]
#   dx_hat (est)   =  7.5244
#   d_hat  (est)   =  1.2033
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -8.1804
# [mpc initial condition]
#   dX0            =  7.5244
# [mpc output]
#   du_cmd         = -18.3862
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.00:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.6111
#   vz_trim        =  0.0000
#   dx_meas        =  7.6111
# [observer]
#   dx_hat (est)   =  7.4239
#   d_hat  (est)   =  1.2552
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -8.5338
# [mpc initial condition]
#   dX0            =  7.4239
# [mpc output]
#   du_cmd         = -18.0328
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.05:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.5023
#   vz_trim        =  0.0000
#   dx_meas        =  7.5023
# [observer]
#   dx_hat (est)   =  7.3226
#   d_hat  (est)   =  1.3023
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -8.8537
# [mpc initial condition]
#   dX0            =  7.3226
# [mpc output]
#   du_cmd         = -17.7130
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.10:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.3935
#   vz_trim        =  0.0000
#   dx_meas        =  7.3935
# [observer]
#   dx_hat (est)   =  7.2207
#   d_hat  (est)   =  1.3448
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -9.1428
# [mpc initial condition]
#   dX0            =  7.2207
# [mpc output]
#   du_cmd         = -17.4239
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.15:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.2848
#   vz_trim        =  0.0000
#   dx_meas        =  7.2848
# [observer]
#   dx_hat (est)   =  7.1182
#   d_hat  (est)   =  1.3833
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -9.4042
# [mpc initial condition]
#   dX0            =  7.1182
# [mpc output]
#   du_cmd         = -17.1624
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.20:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.1761
#   vz_trim        =  0.0000
#   dx_meas        =  7.1761
# [observer]
#   dx_hat (est)   =  7.0151
#   d_hat  (est)   =  1.4180
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -9.6406
# [mpc initial condition]
#   dX0            =  7.0151
# [mpc output]
#   du_cmd         = -16.9261
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.25:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.0674
#   vz_trim        =  0.0000
#   dx_meas        =  7.0674
# [observer]
#   dx_hat (est)   =  6.9116
#   d_hat  (est)   =  1.4494
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -9.8538
# [mpc initial condition]
#   dX0            =  6.9116
# [mpc output]
#   du_cmd         = -16.7128
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.30:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.9587
#   vz_trim        =  0.0000
#   dx_meas        =  6.9587
# [observer]
#   dx_hat (est)   =  6.8075
#   d_hat  (est)   =  1.4777
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -10.0461
# [mpc initial condition]
#   dX0            =  6.8075
# [mpc output]
#   du_cmd         = -16.5205
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.35:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.8500
#   vz_trim        =  0.0000
#   dx_meas        =  6.8500
# [observer]
#   dx_hat (est)   =  6.7030
#   d_hat  (est)   =  1.5032
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -10.2195
# [mpc initial condition]
#   dX0            =  6.7030
# [mpc output]
#   du_cmd         = -16.3472
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.7413
#   vz_trim        =  0.0000
#   dx_meas        =  6.7413
# [observer]
#   dx_hat (est)   =  6.5981
#   d_hat  (est)   =  1.5262
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -10.3757
# [mpc initial condition]
#   dX0            =  6.5981
# [mpc output]
#   du_cmd         = -16.1910
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.6326
#   vz_trim        =  0.0000
#   dx_meas        =  6.6326
# [observer]
#   dx_hat (est)   =  6.4928
#   d_hat  (est)   =  1.5469
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -10.5164
# [mpc initial condition]
#   dX0            =  6.4928
# [mpc output]
#   du_cmd         = -16.0502
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.5239
#   vz_trim        =  0.0000
#   dx_meas        =  6.5239
# [observer]
#   dx_hat (est)   =  6.3872
#   d_hat  (est)   =  1.5655
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -10.6432
# [mpc initial condition]
#   dX0            =  6.3872
# [mpc output]
#   du_cmd         = -15.9235
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.4152
#   vz_trim        =  0.0000
#   dx_meas        =  6.4152
# [observer]
#   dx_hat (est)   =  6.2813
#   d_hat  (est)   =  1.5823
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -10.7573
# [mpc initial condition]
#   dX0            =  6.2813
# [mpc output]
#   du_cmd         = -15.8094
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.3065
#   vz_trim        =  0.0000
#   dx_meas        =  6.3065
# [observer]
#   dx_hat (est)   =  6.1751
#   d_hat  (est)   =  1.5974
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -10.8601
# [mpc initial condition]
#   dX0            =  6.1751
# [mpc output]
#   du_cmd         = -15.7066
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.1978
#   vz_trim        =  0.0000
#   dx_meas        =  6.1978
# [observer]
#   dx_hat (est)   =  6.0687
#   d_hat  (est)   =  1.6110
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -10.9526
# [mpc initial condition]
#   dX0            =  6.0687
# [mpc output]
#   du_cmd         = -15.6140
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.0891
#   vz_trim        =  0.0000
#   dx_meas        =  6.0891
# [observer]
#   dx_hat (est)   =  5.9620
#   d_hat  (est)   =  1.6233
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.0359
# [mpc initial condition]
#   dX0            =  5.9620
# [mpc output]
#   du_cmd         = -15.5307
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.9804
#   vz_trim        =  0.0000
#   dx_meas        =  5.9804
# [observer]
#   dx_hat (est)   =  5.8551
#   d_hat  (est)   =  1.6343
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.1109
# [mpc initial condition]
#   dX0            =  5.8551
# [mpc output]
#   du_cmd         = -15.4557
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.80:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.8717
#   vz_trim        =  0.0000
#   dx_meas        =  5.8717
# [observer]
#   dx_hat (est)   =  5.7481
#   d_hat  (est)   =  1.6442
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.1784
# [mpc initial condition]
#   dX0            =  5.7481
# [mpc output]
#   du_cmd         = -15.3882
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.85:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.7630
#   vz_trim        =  0.0000
#   dx_meas        =  5.7630
# [observer]
#   dx_hat (est)   =  5.6409
#   d_hat  (est)   =  1.6532
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.2392
# [mpc initial condition]
#   dX0            =  5.6409
# [mpc output]
#   du_cmd         = -15.3275
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.90:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.6543
#   vz_trim        =  0.0000
#   dx_meas        =  5.6543
# [observer]
#   dx_hat (est)   =  5.5335
#   d_hat  (est)   =  1.6612
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.2939
# [mpc initial condition]
#   dX0            =  5.5335
# [mpc output]
#   du_cmd         = -15.2728
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.95:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.5456
#   vz_trim        =  0.0000
#   dx_meas        =  5.5456
# [observer]
#   dx_hat (est)   =  5.4260
#   d_hat  (est)   =  1.6685
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.3431
# [mpc initial condition]
#   dX0            =  5.4260
# [mpc output]
#   du_cmd         = -15.2235
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.00:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.4369
#   vz_trim        =  0.0000
#   dx_meas        =  5.4369
# [observer]
#   dx_hat (est)   =  5.3184
#   d_hat  (est)   =  1.6750
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.3874
# [mpc initial condition]
#   dX0            =  5.3184
# [mpc output]
#   du_cmd         = -15.1793
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.05:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.3282
#   vz_trim        =  0.0000
#   dx_meas        =  5.3282
# [observer]
#   dx_hat (est)   =  5.2107
#   d_hat  (est)   =  1.6808
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.4273
# [mpc initial condition]
#   dX0            =  5.2107
# [mpc output]
#   du_cmd         = -15.1394
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.10:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.2195
#   vz_trim        =  0.0000
#   dx_meas        =  5.2195
# [observer]
#   dx_hat (est)   =  5.1028
#   d_hat  (est)   =  1.6861
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.4632
# [mpc initial condition]
#   dX0            =  5.1028
# [mpc output]
#   du_cmd         = -15.1035
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.15:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.1108
#   vz_trim        =  0.0000
#   dx_meas        =  5.1108
# [observer]
#   dx_hat (est)   =  4.9949
#   d_hat  (est)   =  1.6909
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.4955
# [mpc initial condition]
#   dX0            =  4.9949
# [mpc output]
#   du_cmd         = -15.0712
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.20:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.0021
#   vz_trim        =  0.0000
#   dx_meas        =  5.0021
# [observer]
#   dx_hat (est)   =  4.8869
#   d_hat  (est)   =  1.6951
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.5245
# [mpc initial condition]
#   dX0            =  4.8869
# [mpc output]
#   du_cmd         = -15.0421
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.25:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.8934
#   vz_trim        =  0.0000
#   dx_meas        =  4.8934
# [observer]
#   dx_hat (est)   =  4.7789
#   d_hat  (est)   =  1.6990
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.5507
# [mpc initial condition]
#   dX0            =  4.7789
# [mpc output]
#   du_cmd         = -15.0159
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.30:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.7847
#   vz_trim        =  0.0000
#   dx_meas        =  4.7847
# [observer]
#   dx_hat (est)   =  4.6708
#   d_hat  (est)   =  1.7025
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.5743
# [mpc initial condition]
#   dX0            =  4.6708
# [mpc output]
#   du_cmd         = -14.9924
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.35:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.6760
#   vz_trim        =  0.0000
#   dx_meas        =  4.6760
# [observer]
#   dx_hat (est)   =  4.5626
#   d_hat  (est)   =  1.7056
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.5955
# [mpc initial condition]
#   dX0            =  4.5626
# [mpc output]
#   du_cmd         = -14.9712
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.5673
#   vz_trim        =  0.0000
#   dx_meas        =  4.5673
# [observer]
#   dx_hat (est)   =  4.4543
#   d_hat  (est)   =  1.7084
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6146
# [mpc initial condition]
#   dX0            =  4.4543
# [mpc output]
#   du_cmd         = -14.9521
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.4585
#   vz_trim        =  0.0000
#   dx_meas        =  4.4585
# [observer]
#   dx_hat (est)   =  4.3461
#   d_hat  (est)   =  1.7109
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6317
# [mpc initial condition]
#   dX0            =  4.3461
# [mpc output]
#   du_cmd         = -14.9350
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.3498
#   vz_trim        =  0.0000
#   dx_meas        =  4.3498
# [observer]
#   dx_hat (est)   =  4.2377
#   d_hat  (est)   =  1.7132
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6472
# [mpc initial condition]
#   dX0            =  4.2377
# [mpc output]
#   du_cmd         = -14.9195
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.2411
#   vz_trim        =  0.0000
#   dx_meas        =  4.2411
# [observer]
#   dx_hat (est)   =  4.1294
#   d_hat  (est)   =  1.7152
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6611
# [mpc initial condition]
#   dX0            =  4.1294
# [mpc output]
#   du_cmd         = -14.9056
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.1324
#   vz_trim        =  0.0000
#   dx_meas        =  4.1324
# [observer]
#   dx_hat (est)   =  4.0210
#   d_hat  (est)   =  1.7171
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6736
# [mpc initial condition]
#   dX0            =  4.0210
# [mpc output]
#   du_cmd         = -14.8931
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.0238
#   vz_trim        =  0.0000
#   dx_meas        =  4.0238
# [observer]
#   dx_hat (est)   =  3.9126
#   d_hat  (est)   =  1.7187
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6849
# [mpc initial condition]
#   dX0            =  3.9126
# [mpc output]
#   du_cmd         = -14.8818
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.9150
#   vz_trim        =  0.0000
#   dx_meas        =  3.9150
# [observer]
#   dx_hat (est)   =  3.8041
#   d_hat  (est)   =  1.7202
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6950
# [mpc initial condition]
#   dX0            =  3.8041
# [mpc output]
#   du_cmd         = -14.8717
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.8063
#   vz_trim        =  0.0000
#   dx_meas        =  3.8063
# [observer]
#   dx_hat (est)   =  3.6956
#   d_hat  (est)   =  1.7216
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7041
# [mpc initial condition]
#   dX0            =  3.6956
# [mpc output]
#   du_cmd         = -14.8626
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.80:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.6976
#   vz_trim        =  0.0000
#   dx_meas        =  3.6976
# [observer]
#   dx_hat (est)   =  3.5871
#   d_hat  (est)   =  1.7228
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7123
# [mpc initial condition]
#   dX0            =  3.5871
# [mpc output]
#   du_cmd         = -14.8544
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.85:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.5889
#   vz_trim        =  0.0000
#   dx_meas        =  3.5889
# [observer]
#   dx_hat (est)   =  3.4786
#   d_hat  (est)   =  1.7238
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7197
# [mpc initial condition]
#   dX0            =  3.4786
# [mpc output]
#   du_cmd         = -14.8470
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.90:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.4802
#   vz_trim        =  0.0000
#   dx_meas        =  3.4802
# [observer]
#   dx_hat (est)   =  3.3700
#   d_hat  (est)   =  1.7248
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7263
# [mpc initial condition]
#   dX0            =  3.3700
# [mpc output]
#   du_cmd         = -14.8404
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.95:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.3715
#   vz_trim        =  0.0000
#   dx_meas        =  3.3715
# [observer]
#   dx_hat (est)   =  3.2615
#   d_hat  (est)   =  1.7257
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7323
# [mpc initial condition]
#   dX0            =  3.2615
# [mpc output]
#   du_cmd         = -14.8343
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.00:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.2628
#   vz_trim        =  0.0000
#   dx_meas        =  3.2628
# [observer]
#   dx_hat (est)   =  3.1529
#   d_hat  (est)   =  1.7265
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7378
# [mpc initial condition]
#   dX0            =  3.1529
# [mpc output]
#   du_cmd         = -14.8289
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.05:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.1541
#   vz_trim        =  0.0000
#   dx_meas        =  3.1541
# [observer]
#   dx_hat (est)   =  3.0443
#   d_hat  (est)   =  1.7272
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7426
# [mpc initial condition]
#   dX0            =  3.0443
# [mpc output]
#   du_cmd         = -14.8241
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.10:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.0446
#   vz_trim        =  0.0000
#   dx_meas        =  3.0446
# [observer]
#   dx_hat (est)   =  2.9354
#   d_hat  (est)   =  1.7274
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7438
# [mpc initial condition]
#   dX0            =  2.9354
# [mpc output]
#   du_cmd         = -14.8229
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.15:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.9340
#   vz_trim        =  0.0000
#   dx_meas        =  2.9340
# [observer]
#   dx_hat (est)   =  2.8258
#   d_hat  (est)   =  1.7265
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7379
# [mpc initial condition]
#   dX0            =  2.8258
# [mpc output]
#   du_cmd         = -14.8288
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.20:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.8234
#   vz_trim        =  0.0000
#   dx_meas        =  2.8234
# [observer]
#   dx_hat (est)   =  2.7158
#   d_hat  (est)   =  1.7251
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7280
# [mpc initial condition]
#   dX0            =  2.7158
# [mpc output]
#   du_cmd         = -14.8387
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.25:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.7135
#   vz_trim        =  0.0000
#   dx_meas        =  2.7135
# [observer]
#   dx_hat (est)   =  2.6058
#   d_hat  (est)   =  1.7237
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7186
# [mpc initial condition]
#   dX0            =  2.6058
# [mpc output]
#   du_cmd         = -14.8480
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.30:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.6047
#   vz_trim        =  0.0000
#   dx_meas        =  2.6047
# [observer]
#   dx_hat (est)   =  2.4961
#   d_hat  (est)   =  1.7230
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7142
# [mpc initial condition]
#   dX0            =  2.4961
# [mpc output]
#   du_cmd         = -14.8524
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.35:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.4971
#   vz_trim        =  0.0000
#   dx_meas        =  2.4971
# [observer]
#   dx_hat (est)   =  2.3873
#   d_hat  (est)   =  1.7236
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7181
# [mpc initial condition]
#   dX0            =  2.3873
# [mpc output]
#   du_cmd         = -14.8486
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.3907
#   vz_trim        =  0.0000
#   dx_meas        =  2.3907
# [observer]
#   dx_hat (est)   =  2.2795
#   d_hat  (est)   =  1.7257
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7321
# [mpc initial condition]
#   dX0            =  2.2795
# [mpc output]
#   du_cmd         = -14.8345
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.2856
#   vz_trim        =  0.0000
#   dx_meas        =  2.2856
# [observer]
#   dx_hat (est)   =  2.1728
#   d_hat  (est)   =  1.7293
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7570
# [mpc initial condition]
#   dX0            =  2.1728
# [mpc output]
#   du_cmd         = -14.8096
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.1815
#   vz_trim        =  0.0000
#   dx_meas        =  2.1815
# [observer]
#   dx_hat (est)   =  2.0674
#   d_hat  (est)   =  1.7346
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7926
# [mpc initial condition]
#   dX0            =  2.0674
# [mpc output]
#   du_cmd         = -14.2434
#   u_cmd (abs)    =  40.6307
# -------------------------------
#
# Simulating time 3.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.0836
#   vz_trim        =  0.0000
#   dx_meas        =  2.0836
# [observer]
#   dx_hat (est)   =  1.9691
#   d_hat  (est)   =  1.7443
#   du_prev        = -26.0359
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.8588
# [mpc initial condition]
#   dX0            =  1.9691
# [mpc output]
#   du_cmd         = -13.5664
#   u_cmd (abs)    =  41.2414
# -------------------------------
#
# Simulating time 3.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.9925
#   vz_trim        =  0.0000
#   dx_meas        =  1.9925
# [observer]
#   dx_hat (est)   =  1.8787
#   d_hat  (est)   =  1.7584
#   du_prev        = -25.4252
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.9543
# [mpc initial condition]
#   dX0            =  1.8787
# [mpc output]
#   du_cmd         = -12.9435
#   u_cmd (abs)    =  41.7688
# -------------------------------
#
# Simulating time 3.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.9073
#   vz_trim        =  0.0000
#   dx_meas        =  1.9073
# [observer]
#   dx_hat (est)   =  1.7950
#   d_hat  (est)   =  1.7755
#   du_prev        = -24.8978
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -12.0712
# [mpc initial condition]
#   dX0            =  1.7950
# [mpc output]
#   du_cmd         = -12.3666
#   u_cmd (abs)    =  42.2289
# -------------------------------
#
# Simulating time 3.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.8274
#   vz_trim        =  0.0000
#   dx_meas        =  1.8274
# [observer]
#   dx_hat (est)   =  1.7170
#   d_hat  (est)   =  1.7950
#   du_prev        = -24.4378
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -12.2033
# [mpc initial condition]
#   dX0            =  1.7170
# [mpc output]
#   du_cmd         = -11.8293
#   u_cmd (abs)    =  42.6341
# -------------------------------
#
# Simulating time 3.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.7519
#   vz_trim        =  0.0000
#   dx_meas        =  1.7519
# [observer]
#   dx_hat (est)   =  1.6440
#   d_hat  (est)   =  1.8160
#   du_prev        = -24.0326
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -12.3459
# [mpc initial condition]
#   dX0            =  1.6440
# [mpc output]
#   du_cmd         = -11.3262
#   u_cmd (abs)    =  42.9945
# -------------------------------
#
# Simulating time 3.80:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.6806
#   vz_trim        =  0.0000
#   dx_meas        =  1.6806
# [observer]
#   dx_hat (est)   =  1.5753
#   d_hat  (est)   =  1.8379
#   du_prev        = -23.6722
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -12.4953
# [mpc initial condition]
#   dX0            =  1.5753
# [mpc output]
#   du_cmd         = -10.8533
#   u_cmd (abs)    =  43.3181
# -------------------------------
#
# Simulating time 3.85:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.6128
#   vz_trim        =  0.0000
#   dx_meas        =  1.6128
# [observer]
#   dx_hat (est)   =  1.5105
#   d_hat  (est)   =  1.8605
#   du_prev        = -23.3485
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -12.6484
# [mpc initial condition]
#   dX0            =  1.5105
# [mpc output]
#   du_cmd         = -10.4068
#   u_cmd (abs)    =  43.6115
# -------------------------------
#
# Simulating time 3.90:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.5484
#   vz_trim        =  0.0000
#   dx_meas        =  1.5484
# [observer]
#   dx_hat (est)   =  1.4491
#   d_hat  (est)   =  1.8832
#   du_prev        = -23.0551
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -12.8029
# [mpc initial condition]
#   dX0            =  1.4491
# [mpc output]
#   du_cmd         = -9.9838
#   u_cmd (abs)    =  43.8800
# -------------------------------
#
# Simulating time 3.95:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.4869
#   vz_trim        =  0.0000
#   dx_meas        =  1.4869
# [observer]
#   dx_hat (est)   =  1.3908
#   d_hat  (est)   =  1.9058
#   du_prev        = -22.7867
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -12.9569
# [mpc initial condition]
#   dX0            =  1.3908
# [mpc output]
#   du_cmd         = -9.5820
#   u_cmd (abs)    =  44.1278
# -------------------------------
#
# Simulating time 4.00:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.4281
#   vz_trim        =  0.0000
#   dx_meas        =  1.4281
# [observer]
#   dx_hat (est)   =  1.3352
#   d_hat  (est)   =  1.9282
#   du_prev        = -22.5389
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -13.1090
# [mpc initial condition]
#   dX0            =  1.3352
# [mpc output]
#   du_cmd         = -9.1993
#   u_cmd (abs)    =  44.3584
# -------------------------------
#
# Simulating time 4.05:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.3718
#   vz_trim        =  0.0000
#   dx_meas        =  1.3718
# [observer]
#   dx_hat (est)   =  1.2822
#   d_hat  (est)   =  1.9501
#   du_prev        = -22.3083
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -13.2581
# [mpc initial condition]
#   dX0            =  1.2822
# [mpc output]
#   du_cmd         = -8.8339
#   u_cmd (abs)    =  44.5747
# -------------------------------
#
# Simulating time 4.10:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.3178
#   vz_trim        =  0.0000
#   dx_meas        =  1.3178
# [observer]
#   dx_hat (est)   =  1.2315
#   d_hat  (est)   =  1.9715
#   du_prev        = -22.0920
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -13.4034
# [mpc initial condition]
#   dX0            =  1.2315
# [mpc output]
#   du_cmd         = -8.4844
#   u_cmd (abs)    =  44.7788
# -------------------------------
#
# Simulating time 4.15:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.2660
#   vz_trim        =  0.0000
#   dx_meas        =  1.2660
# [observer]
#   dx_hat (est)   =  1.1829
#   d_hat  (est)   =  1.9922
#   du_prev        = -21.8878
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -13.5443
# [mpc initial condition]
#   dX0            =  1.1829
# [mpc output]
#   du_cmd         = -8.1497
#   u_cmd (abs)    =  44.9727
# -------------------------------
#
# Simulating time 4.20:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.2162
#   vz_trim        =  0.0000
#   dx_meas        =  1.2162
# [observer]
#   dx_hat (est)   =  1.1363
#   d_hat  (est)   =  2.0122
#   du_prev        = -21.6939
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -13.6802
# [mpc initial condition]
#   dX0            =  1.1363
# [mpc output]
#   du_cmd         = -7.8286
#   u_cmd (abs)    =  45.1578
# -------------------------------
#
# Simulating time 4.25:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.1684
#   vz_trim        =  0.0000
#   dx_meas        =  1.1684
# [observer]
#   dx_hat (est)   =  1.0915
#   d_hat  (est)   =  2.0315
#   du_prev        = -21.5088
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -13.8111
# [mpc initial condition]
#   dX0            =  1.0915
# [mpc output]
#   du_cmd         = -7.5203
#   u_cmd (abs)    =  45.3352
# -------------------------------
#
# Simulating time 4.30:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.1223
#   vz_trim        =  0.0000
#   dx_meas        =  1.1223
# [observer]
#   dx_hat (est)   =  1.0486
#   d_hat  (est)   =  2.0499
#   du_prev        = -21.3314
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -13.9367
# [mpc initial condition]
#   dX0            =  1.0486
# [mpc output]
#   du_cmd         = -7.2241
#   u_cmd (abs)    =  45.5058
# -------------------------------
#
# Simulating time 4.35:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.0780
#   vz_trim        =  0.0000
#   dx_meas        =  1.0780
# [observer]
#   dx_hat (est)   =  1.0072
#   d_hat  (est)   =  2.0676
#   du_prev        = -21.1608
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.0570
# [mpc initial condition]
#   dX0            =  1.0072
# [mpc output]
#   du_cmd         = -6.9393
#   u_cmd (abs)    =  45.6703
# -------------------------------
#
# Simulating time 4.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.0354
#   vz_trim        =  0.0000
#   dx_meas        =  1.0354
# [observer]
#   dx_hat (est)   =  0.9675
#   d_hat  (est)   =  2.0846
#   du_prev        = -20.9963
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.1720
# [mpc initial condition]
#   dX0            =  0.9675
# [mpc output]
#   du_cmd         = -6.6654
#   u_cmd (abs)    =  45.8292
# -------------------------------
#
# Simulating time 4.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.9944
#   vz_trim        =  0.0000
#   dx_meas        =  0.9944
# [observer]
#   dx_hat (est)   =  0.9292
#   d_hat  (est)   =  2.1007
#   du_prev        = -20.8375
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.2819
# [mpc initial condition]
#   dX0            =  0.9292
# [mpc output]
#   du_cmd         = -6.4019
#   u_cmd (abs)    =  45.9829
# -------------------------------
#
# Simulating time 4.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.9549
#   vz_trim        =  0.0000
#   dx_meas        =  0.9549
# [observer]
#   dx_hat (est)   =  0.8924
#   d_hat  (est)   =  2.1161
#   du_prev        = -20.6838
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.3867
# [mpc initial condition]
#   dX0            =  0.8924
# [mpc output]
#   du_cmd         = -6.1483
#   u_cmd (abs)    =  46.1317
# -------------------------------
#
# Simulating time 4.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.9169
#   vz_trim        =  0.0000
#   dx_meas        =  0.9169
# [observer]
#   dx_hat (est)   =  0.8570
#   d_hat  (est)   =  2.1308
#   du_prev        = -20.5350
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.4866
# [mpc initial condition]
#   dX0            =  0.8570
# [mpc output]
#   du_cmd         = -5.9043
#   u_cmd (abs)    =  46.2758
# -------------------------------
#
# Simulating time 4.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.8803
#   vz_trim        =  0.0000
#   dx_meas        =  0.8803
# [observer]
#   dx_hat (est)   =  0.8229
#   d_hat  (est)   =  2.1448
#   du_prev        = -20.3909
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.5818
# [mpc initial condition]
#   dX0            =  0.8229
# [mpc output]
#   du_cmd         = -5.6695
#   u_cmd (abs)    =  46.4154
# -------------------------------
#
# Simulating time 4.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.8451
#   vz_trim        =  0.0000
#   dx_meas        =  0.8451
# [observer]
#   dx_hat (est)   =  0.7901
#   d_hat  (est)   =  2.1582
#   du_prev        = -20.2512
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.6725
# [mpc initial condition]
#   dX0            =  0.7901
# [mpc output]
#   du_cmd         = -5.4435
#   u_cmd (abs)    =  46.5507
# -------------------------------
#
# Simulating time 4.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.8113
#   vz_trim        =  0.0000
#   dx_meas        =  0.8113
# [observer]
#   dx_hat (est)   =  0.7585
#   d_hat  (est)   =  2.1709
#   du_prev        = -20.1160
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.7590
# [mpc initial condition]
#   dX0            =  0.7585
# [mpc output]
#   du_cmd         = -5.2261
#   u_cmd (abs)    =  46.6816
# -------------------------------
#
# Simulating time 4.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.7787
#   vz_trim        =  0.0000
#   dx_meas        =  0.7787
# [observer]
#   dx_hat (est)   =  0.7282
#   d_hat  (est)   =  2.1830
#   du_prev        = -19.9850
# [reference]
# ...
#
# Simulating time 13.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0006
#   vz_trim        =  0.0000
#   dx_meas        =  0.0006
# [observer]
#   dx_hat (est)   =  0.0005
#   d_hat  (est)   =  2.4513
#   du_prev        = -16.6691
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6654
# [mpc initial condition]
#   dX0            =  0.0005
# [mpc output]
#   du_cmd         = -0.0037
#   u_cmd (abs)    =  49.9976
# -------------------------------
#
# Simulating time 13.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0005
#   vz_trim        =  0.0000
#   dx_meas        =  0.0005
# [observer]
#   dx_hat (est)   =  0.0005
#   d_hat  (est)   =  2.4513
#   du_prev        = -16.6690
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6654
# [mpc initial condition]
#   dX0            =  0.0005
# [mpc output]
#   du_cmd         = -0.0035
#   u_cmd (abs)    =  49.9977
# -------------------------------
#
# Simulating time 13.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0005
#   vz_trim        =  0.0000
#   dx_meas        =  0.0005
# [observer]
#   dx_hat (est)   =  0.0005
#   d_hat  (est)   =  2.4513
#   du_prev        = -16.6689
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6655
# [mpc initial condition]
#   dX0            =  0.0005
# [mpc output]
#   du_cmd         = -0.0034
#   u_cmd (abs)    =  49.9978
# -------------------------------
#
# Simulating time 13.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0005
#   vz_trim        =  0.0000
#   dx_meas        =  0.0005
# [observer]
#   dx_hat (est)   =  0.0005
#   d_hat  (est)   =  2.4513
#   du_prev        = -16.6689
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6655
# [mpc initial condition]
#   dX0            =  0.0005
# [mpc output]
#   du_cmd         = -0.0032
#   u_cmd (abs)    =  49.9979
# -------------------------------
#
# Simulating time 13.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0005
#   vz_trim        =  0.0000
#   dx_meas        =  0.0005
# [observer]
#   dx_hat (est)   =  0.0004
#   d_hat  (est)   =  2.4513
#   du_prev        = -16.6688
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6656
# [mpc initial condition]
#   dX0            =  0.0004
# [mpc output]
#   du_cmd         = -0.0031
#   u_cmd (abs)    =  49.9980
# -------------------------------
#
# Simulating time 13.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0005
#   vz_trim        =  0.0000
#   dx_meas        =  0.0005
# [observer]
#   dx_hat (est)   =  0.0004
#   d_hat  (est)   =  2.4513
#   du_prev        = -16.6687
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6656
# [mpc initial condition]
#   dX0            =  0.0004
# [mpc output]
#   du_cmd         = -0.0030
#   u_cmd (abs)    =  49.9981
# -------------------------------
#
# Simulating time 13.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0004
#   vz_trim        =  0.0000
#   dx_meas        =  0.0004
# [observer]
#   dx_hat (est)   =  0.0004
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6686
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6657
# [mpc initial condition]
#   dX0            =  0.0004
# [mpc output]
#   du_cmd         = -0.0029
#   u_cmd (abs)    =  49.9982
# -------------------------------
#
# Simulating time 13.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0004
#   vz_trim        =  0.0000
#   dx_meas        =  0.0004
# [observer]
#   dx_hat (est)   =  0.0004
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6685
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6657
# [mpc initial condition]
#   dX0            =  0.0004
# [mpc output]
#   du_cmd         = -0.0027
#   u_cmd (abs)    =  49.9982
# -------------------------------
#
# Simulating time 13.80:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0004
#   vz_trim        =  0.0000
#   dx_meas        =  0.0004
# [observer]
#   dx_hat (est)   =  0.0004
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6684
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6657
# [mpc initial condition]
#   dX0            =  0.0004
# [mpc output]
#   du_cmd         = -0.0026
#   u_cmd (abs)    =  49.9983
# -------------------------------
#
# Simulating time 13.85:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0004
#   vz_trim        =  0.0000
#   dx_meas        =  0.0004
# [observer]
#   dx_hat (est)   =  0.0004
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6684
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6658
# [mpc initial condition]
#   dX0            =  0.0004
# [mpc output]
#   du_cmd         = -0.0025
#   u_cmd (abs)    =  49.9984
# -------------------------------
#
# Simulating time 13.90:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0004
#   vz_trim        =  0.0000
#   dx_meas        =  0.0004
# [observer]
#   dx_hat (est)   =  0.0003
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6683
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6658
# [mpc initial condition]
#   dX0            =  0.0003
# [mpc output]
#   du_cmd         = -0.0024
#   u_cmd (abs)    =  49.9984
# -------------------------------
#
# Simulating time 13.95:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0004
#   vz_trim        =  0.0000
#   dx_meas        =  0.0004
# [observer]
#   dx_hat (est)   =  0.0003
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6682
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6658
# [mpc initial condition]
#   dX0            =  0.0003
# [mpc output]
#   du_cmd         = -0.0023
#   u_cmd (abs)    =  49.9985
# -------------------------------
#
# Simulating time 14.00:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0003
#   vz_trim        =  0.0000
#   dx_meas        =  0.0003
# [observer]
#   dx_hat (est)   =  0.0003
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6682
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6659
# [mpc initial condition]
#   dX0            =  0.0003
# [mpc output]
#   du_cmd         = -0.0022
#   u_cmd (abs)    =  49.9986
# -------------------------------
#
# Simulating time 14.05:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0003
#   vz_trim        =  0.0000
#   dx_meas        =  0.0003
# [observer]
#   dx_hat (est)   =  0.0003
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6681
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6659
# [mpc initial condition]
#   dX0            =  0.0003
# [mpc output]
#   du_cmd         = -0.0021
#   u_cmd (abs)    =  49.9986
# -------------------------------
#
# Simulating time 14.10:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0003
#   vz_trim        =  0.0000
#   dx_meas        =  0.0003
# [observer]
#   dx_hat (est)   =  0.0003
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6680
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6659
# [mpc initial condition]
#   dX0            =  0.0003
# [mpc output]
#   du_cmd         = -0.0020
#   u_cmd (abs)    =  49.9987
# -------------------------------
#
# Simulating time 14.15:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0003
#   vz_trim        =  0.0000
#   dx_meas        =  0.0003
# [observer]
#   dx_hat (est)   =  0.0003
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6680
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6660
# [mpc initial condition]
#   dX0            =  0.0003
# [mpc output]
#   du_cmd         = -0.0020
#   u_cmd (abs)    =  49.9987
# -------------------------------
#
# Simulating time 14.20:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0003
#   vz_trim        =  0.0000
#   dx_meas        =  0.0003
# [observer]
#   dx_hat (est)   =  0.0003
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6679
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6660
# [mpc initial condition]
#   dX0            =  0.0003
# [mpc output]
#   du_cmd         = -0.0019
#   u_cmd (abs)    =  49.9988
# -------------------------------
#
# Simulating time 14.25:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0003
#   vz_trim        =  0.0000
#   dx_meas        =  0.0003
# [observer]
#   dx_hat (est)   =  0.0003
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6679
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6660
# [mpc initial condition]
#   dX0            =  0.0003
# [mpc output]
#   du_cmd         = -0.0018
#   u_cmd (abs)    =  49.9988
# -------------------------------
#
# Simulating time 14.30:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0003
#   vz_trim        =  0.0000
#   dx_meas        =  0.0003
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6678
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6661
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0017
#   u_cmd (abs)    =  49.9989
# -------------------------------
#
# Simulating time 14.35:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0003
#   vz_trim        =  0.0000
#   dx_meas        =  0.0003
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6678
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6661
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0017
#   u_cmd (abs)    =  49.9989
# -------------------------------
#
# Simulating time 14.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0002
#   vz_trim        =  0.0000
#   dx_meas        =  0.0002
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6677
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6661
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0016
#   u_cmd (abs)    =  49.9990
# -------------------------------
#
# Simulating time 14.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0002
#   vz_trim        =  0.0000
#   dx_meas        =  0.0002
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6677
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6661
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0015
#   u_cmd (abs)    =  49.9990
# -------------------------------
#
# Simulating time 14.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0002
#   vz_trim        =  0.0000
#   dx_meas        =  0.0002
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6677
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6661
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0015
#   u_cmd (abs)    =  49.9991
# -------------------------------
#
# Simulating time 14.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0002
#   vz_trim        =  0.0000
#   dx_meas        =  0.0002
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6676
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6662
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0014
#   u_cmd (abs)    =  49.9991
# -------------------------------
#
# Simulating time 14.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0002
#   vz_trim        =  0.0000
#   dx_meas        =  0.0002
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6676
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6662
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0013
#   u_cmd (abs)    =  49.9991
# -------------------------------
#
# Simulating time 14.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0002
#   vz_trim        =  0.0000
#   dx_meas        =  0.0002
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6675
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6662
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0013
#   u_cmd (abs)    =  49.9992
# -------------------------------
#
# Simulating time 14.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0002
#   vz_trim        =  0.0000
#   dx_meas        =  0.0002
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6675
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6662
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0012
#   u_cmd (abs)    =  49.9992
# -------------------------------
#
# Simulating time 14.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0002
#   vz_trim        =  0.0000
#   dx_meas        =  0.0002
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6675
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6662
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0012
#   u_cmd (abs)    =  49.9992
# -------------------------------
#
# Simulating time 14.80:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0002
#   vz_trim        =  0.0000
#   dx_meas        =  0.0002
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6674
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6663
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0011
#   u_cmd (abs)    =  49.9993
# -------------------------------
#
# Simulating time 14.85:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0002
#   vz_trim        =  0.0000
#   dx_meas        =  0.0002
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6674
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6663
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0011
#   u_cmd (abs)    =  49.9993
# -------------------------------
#
# Simulating time 14.90:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0002
#   vz_trim        =  0.0000
#   dx_meas        =  0.0002
# [observer]
#   dx_hat (est)   =  0.0002
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6674
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6663
# [mpc initial condition]
#   dX0            =  0.0002
# [mpc output]
#   du_cmd         = -0.0010
#   u_cmd (abs)    =  49.9993
# -------------------------------
#
# Simulating time 14.95:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0002
#   vz_trim        =  0.0000
#   dx_meas        =  0.0002
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4514
#   du_prev        = -16.6673
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6663
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0010
#   u_cmd (abs)    =  49.9994
# -------------------------------
# AppLayout(children=(HBox(children=(Play(value=0, description='Press play', max=299, step=2), IntSlider(value=0…

# %%
##################################

        # SIMU INFO

##################################
print("=== Simulation info ===")
print(f"Ts           = {Ts} s")
print(f"Horizon H    = {H} s ({int(H/Ts)} steps)")
print(f"Sim time     = {sim_time} s")
print(f"Method       = linear")
print("")



##################################

    # Input constraints INFO

##################################

print("=== Input constraints check ===")

print(f"d1   in [{np.rad2deg(u_cl[0,:].min()):.3f}, {np.rad2deg(u_cl[0,:].max()):.3f}]   (limit ±15°)")
print(f"d2   in [{np.rad2deg(u_cl[1,:].min()):.3f}, {np.rad2deg(u_cl[1,:].max()):.3f}]   (limit ±15°)")
print(f"Pavg in [{u_cl[2,:].min():.2f}, {u_cl[2,:].max():.2f}]   (limit [40,80])")
print(f"Pdif in [{u_cl[3,:].min():.2f}, {u_cl[3,:].max():.2f}]   (limit ±20)")
print("")


import numpy as np

alpha = np.rad2deg(x_cl[3, :])
beta  = np.rad2deg(x_cl[4, :])


##################################

    # Angle constraints INFO

##################################

print("=== Angle constraints check ===")
print(f"alpha max |α| = {np.abs(alpha).max():.2f} deg   (limit 10 deg)")
print(f"beta  max |β| = {np.abs(beta).max():.2f} deg   (limit 10 deg)")
print("")
# Out:
# === Simulation info ===
# Ts           = 0.05 s
# Horizon H    = 5.0 s (100 steps)
# Sim time     = 15 s
# Method       = linear
#
# === Input constraints check ===
# d1   in [-14.900, 14.900]   (limit ±15°)
# d2   in [-14.900, 14.900]   (limit ±15°)
# Pavg in [40.10, 50.00]   (limit [40,80])
# Pdif in [-0.11, 0.06]   (limit ±20)
#
# === Angle constraints check ===
# alpha max |α| = 11.96 deg   (limit 10 deg)
# beta  max |β| = 11.58 deg   (limit 10 deg)

# %%
def settling_time(t, signal, tol=0.15):
    ref = 0.0
    err = np.abs(signal - ref)
    idx = np.where(err <= tol)[0]
    if len(idx) == 0:
        return None
    for k in idx:
        if np.all(err[k:] <= tol):
            return t[k]
    return None

def print_settling(name, t, sig, tol):
    ts = settling_time(t, sig, tol)
    if ts is None:
        print(f"{name} settling time: > {t[-1]:.2f} s (not settled)")
    else:
        print(f"{name} settling time: {ts:.2f} s")

##################################

    # Settling time INFO

##################################
print("=== Settling time ===")
print_settling("vx", t_cl, x_cl[6,:], tol=0.05)
print_settling("vy", t_cl, x_cl[7,:], tol=0.05)
print_settling("vz", t_cl, x_cl[8,:], tol=0.05)
print("")

Xf_x = mpc.mpc_x.Xf  # terminal set xvel
inside = [
    Xf_x.contains(x_cl[mpc.mpc_x.x_ids, k] - mpc.mpc_x.xs)
    for k in range(x_cl.shape[1])
]

first_inside = next((t_cl[k] for k,v in enumerate(inside) if v), None)

##################################

    # Terminal set entry INFO

##################################

print("=== Terminal set entry ===")
print(f"xvel enters Xf at t = {first_inside:.2f} s")
print("")


##################################

      # Trim values INFO

##################################

print("=== TRIM VALUES ===")

print("\n--- xvel ---")
print("xs_xvel =", mpc.mpc_x.xs)
print("us_xvel =", mpc.mpc_x.us)

print("\n--- yvel ---")
print("xs_yvel =", mpc.mpc_y.xs)
print("us_yvel =", mpc.mpc_y.us)

print("\n--- zvel ---")
print("xs_zvel =", mpc.mpc_z.xs)
print("us_zvel =", mpc.mpc_z.us)

print("\n--- roll ---")
print("xs_roll =", mpc.mpc_roll.xs)
print("us_roll =", mpc.mpc_roll.us)
# Out:
# === Settling time ===
# vx settling time: 4.35 s
# vy settling time: 4.40 s
# vz settling time: 8.05 s
#
# === Terminal set entry ===
# xvel enters Xf at t = 3.10 s
#
# === TRIM VALUES ===
#
# --- xvel ---
# xs_xvel = [0. 0. 0.]
# us_xvel = [0.]
#
# --- yvel ---
# xs_yvel = [0. 0. 0.]
# us_yvel = [0.]
#
# --- zvel ---
# xs_zvel = [0.]
# us_zvel = [66.66666667]
#
# --- roll ---
# xs_roll = [0. 0.]
# us_roll = [0.]

# %%
import matplotlib.pyplot as plt
plt.figure()

# Open-loop prediction of vx at time k=0 (FULL state index!)
plt.plot(
    t_ol[:, 0],
    x_ol[6, :, 0],     # <-- index 6 = vx
    '--',
    label="OL prediction vx"
)

# Closed-loop vx
plt.plot(
    t_cl,
    x_cl[6, :],
    label="CL vx"
)

plt.xlabel("time [s]")
plt.ylabel("vx [m/s]")
plt.legend()
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()

# Open-loop prediction of vx at time k=0 (FULL state index!)
plt.plot(
    t_ol[:, 0],
    x_ol[7, :, 0],     # <-- index 6 = vx
    '--',
    label="OL prediction vy"
)

# Closed-loop vx
plt.plot(
    t_cl,
    x_cl[7, :],
    label="CL vy"
)

plt.xlabel("time [s]")
plt.ylabel("vy [m/s]")
plt.legend()
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()

# Open-loop prediction of vx at time k=0 (FULL state index!)
plt.plot(
    t_ol[:, 0],
    x_ol[8, :, 0],     # <-- index 6 = vx
    '--',
    label="OL prediction vz"
)

# Closed-loop vx
plt.plot(
    t_cl,
    x_cl[8, :],
    label="CL vz"
)

plt.xlabel("time [s]")
plt.ylabel("vz [m/s]")
plt.legend()
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()

# Open-loop prediction of vx at time k=0 (FULL state index!)
plt.plot(
    t_ol[:, 0],
    x_ol[5, :, 0],     # <-- index 6 = vx
    '--',
    label="OL prediction roll"
)

# Closed-loop vx
plt.plot(
    t_cl,
    x_cl[5, :],
    label="CL roll"
)

plt.xlabel("time [s]")
plt.ylabel("roll [rad]")
plt.legend()
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
d_hat = np.array(mpc.mpc_z.d_hat_log)  # z-velocity MPC
t = t_cl[:len(d_hat)]

plt.figure()
plt.plot(t, d_hat, linewidth=2)
plt.xlabel("Time [s]")
plt.ylabel("Estimated disturbance $\hat d$")
plt.title("Estimated disturbance (offset-free MPC)")
plt.grid(True)
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\h'
# <>:7: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\natha\AppData\Local\Temp\ipykernel_30424\1375503577.py:7: SyntaxWarning: invalid escape sequence '\h'
#   plt.ylabel("Estimated disturbance $\hat d$")
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
