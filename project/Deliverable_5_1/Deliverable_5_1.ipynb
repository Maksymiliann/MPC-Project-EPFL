# %%
# %load_ext autoreload
# %autoreload 2

# Get parent directory and add to sys.path
import os; import sys
import numpy as np
parent_dir = os.path.dirname(os.getcwd())
sys.path.append(parent_dir)

# Require ipympl
# %matplotlib widget

# %%
# MPC import
from Deliverable_5_1.LinearMPC_t.MPCVelControl import MPCVelControl
from PIControl.PIControl import PIControl

from src.rocket import Rocket
from src.vel_rocket_vis import RocketVis, plot_static_states_inputs

rocket_obj_path = os.path.join(parent_dir, "Cartoon_rocket.obj")
rocket_params_path = os.path.join(parent_dir, "rocket.yaml")

# %%
Ts = 0.05
sim_time = 15; H = 5.0
x0 = np.array([0, 0, 0, 0, 0, 0, 5, 5, 10, 0, 0, 1])  # initial state
x_target = np.zeros((12,))

rocket = Rocket(Ts=Ts, model_params_filepath=rocket_params_path)
mpc = MPCVelControl().new_controller(rocket, Ts, H)

# Static mass change and zero fuel rate
rocket.mass = 1.5
rocket.fuel_rate = 0.0
t_cl, x_cl, u_cl, t_ol, x_ol, u_ol, ref = rocket.simulate_control(mpc, sim_time, H, x0, x_target=x_target, method='nonlinear')

vis = RocketVis(rocket, rocket_obj_path)
vis.anim_rate = 1.0
vis.animate(t_cl[:-1], x_cl[:,:-1], u_cl, Ref=ref[:,:-1], T_ol=t_ol[...,:-1], X_ol=x_ol, U_ol=u_ol);
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Simulating time 0.00:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  10.0000
#   vz_trim        =  0.0000
#   dx_meas        =  10.0000
# [observer]
#   dx_hat (est)   =  10.0000
#   d_hat  (est)   =  0.0000
#   du_prev        =  0.0000
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -0.0000
# [mpc initial condition]
#   dX0            =  10.0000
# [mpc output]
#   du_cmd         = -26.5667
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.05:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.8777
#   vz_trim        =  0.0000
#   dx_meas        =  9.8777
# [observer]
#   dx_hat (est)   =  9.6824
#   d_hat  (est)   = -0.5869
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) =  3.9899
# [mpc initial condition]
#   dX0            =  9.6824
# [mpc output]
#   du_cmd         = -30.5565
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.10:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.7601
#   vz_trim        =  0.0000
#   dx_meas        =  9.7601
# [observer]
#   dx_hat (est)   =  9.5354
#   d_hat  (est)   = -0.2138
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) =  1.4534
# [mpc initial condition]
#   dX0            =  9.5354
# [mpc output]
#   du_cmd         = -28.0201
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.15:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.6617
#   vz_trim        =  0.0000
#   dx_meas        =  9.6617
# [observer]
#   dx_hat (est)   =  9.4556
#   d_hat  (est)   =  0.3926
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -2.6691
# [mpc initial condition]
#   dX0            =  9.4556
# [mpc output]
#   du_cmd         = -23.8976
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.20:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.5304
#   vz_trim        =  0.0000
#   dx_meas        =  9.5304
# [observer]
#   dx_hat (est)   =  9.3546
#   d_hat  (est)   =  0.7516
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -5.1097
# [mpc initial condition]
#   dX0            =  9.3546
# [mpc output]
#   du_cmd         = -21.4570
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.25:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.3600
#   vz_trim        =  0.0000
#   dx_meas        =  9.3600
# [observer]
#   dx_hat (est)   =  9.2022
#   d_hat  (est)   =  0.7774
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -5.2855
# [mpc initial condition]
#   dX0            =  9.2022
# [mpc output]
#   du_cmd         = -21.2812
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
#  State beta violation: -0.19 < -0.17,
#  State alpha violation: 0.20 > 0.17,
# Simulating time 0.30:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.1824
#   vz_trim        =  0.0000
#   dx_meas        =  9.1824
# [observer]
#   dx_hat (est)   =  9.0259
#   d_hat  (est)   =  0.6825
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -4.6398
# [mpc initial condition]
#   dX0            =  9.0259
# [mpc output]
#   du_cmd         = -21.9268
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
#  State beta violation: -0.20 < -0.17,
#  State alpha violation: 0.21 > 0.17,
# Simulating time 0.35:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  9.0084
#   vz_trim        =  0.0000
#   dx_meas        =  9.0084
# [observer]
#   dx_hat (est)   =  8.8472
#   d_hat  (est)   =  0.5986
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -4.0695
# [mpc initial condition]
#   dX0            =  8.8472
# [mpc output]
#   du_cmd         = -22.4971
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
#  State beta violation: -0.19 < -0.17,
#  State alpha violation: 0.19 > 0.17,
# Simulating time 0.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.9081
#   vz_trim        =  0.0000
#   dx_meas        =  8.9081
# [observer]
#   dx_hat (est)   =  8.7427
#   d_hat  (est)   =  0.8911
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -6.0584
# [mpc initial condition]
#   dX0            =  8.7427
# [mpc output]
#   du_cmd         = -20.5083
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.8104
#   vz_trim        =  0.0000
#   dx_meas        =  8.8104
# [observer]
#   dx_hat (est)   =  8.6596
#   d_hat  (est)   =  1.2162
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -8.2685
# [mpc initial condition]
#   dX0            =  8.6596
# [mpc output]
#   du_cmd         = -18.2982
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.7091
#   vz_trim        =  0.0000
#   dx_meas        =  8.7091
# [observer]
#   dx_hat (est)   =  8.5745
#   d_hat  (est)   =  1.4537
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -9.8833
# [mpc initial condition]
#   dX0            =  8.5745
# [mpc output]
#   du_cmd         = -16.6834
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.5984
#   vz_trim        =  0.0000
#   dx_meas        =  8.5984
# [observer]
#   dx_hat (est)   =  8.4757
#   d_hat  (est)   =  1.5683
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -10.6622
# [mpc initial condition]
#   dX0            =  8.4757
# [mpc output]
#   du_cmd         = -15.9045
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.4814
#   vz_trim        =  0.0000
#   dx_meas        =  8.4814
# [observer]
#   dx_hat (est)   =  8.3644
#   d_hat  (est)   =  1.5957
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -10.8483
# [mpc initial condition]
#   dX0            =  8.3644
# [mpc output]
#   du_cmd         = -15.7183
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
#  State alpha violation: 0.17 > 0.17,
# Simulating time 0.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.3690
#   vz_trim        =  0.0000
#   dx_meas        =  8.3690
# [observer]
#   dx_hat (est)   =  8.2534
#   d_hat  (est)   =  1.6178
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -10.9987
# [mpc initial condition]
#   dX0            =  8.2534
# [mpc output]
#   du_cmd         = -15.5680
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.2625
#   vz_trim        =  0.0000
#   dx_meas        =  8.2625
# [observer]
#   dx_hat (est)   =  8.1480
#   d_hat  (est)   =  1.6613
#   du_prev        = -26.5666
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.2942
# [mpc initial condition]
#   dX0            =  8.1480
# [mpc output]
#   du_cmd         = -15.2724
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.1553
#   vz_trim        =  0.0000
#   dx_meas        =  8.1553
# [observer]
#   dx_hat (est)   =  8.0430
#   d_hat  (est)   =  1.6965
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.5341
# [mpc initial condition]
#   dX0            =  8.0430
# [mpc output]
#   du_cmd         = -15.0326
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.80:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  8.0464
#   vz_trim        =  0.0000
#   dx_meas        =  8.0464
# [observer]
#   dx_hat (est)   =  7.9359
#   d_hat  (est)   =  1.7132
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6470
# [mpc initial condition]
#   dX0            =  7.9359
# [mpc output]
#   du_cmd         = -14.9196
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.85:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.9368
#   vz_trim        =  0.0000
#   dx_meas        =  7.9368
# [observer]
#   dx_hat (est)   =  7.8271
#   d_hat  (est)   =  1.7177
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6782
# [mpc initial condition]
#   dX0            =  7.8271
# [mpc output]
#   du_cmd         = -14.8885
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.90:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.8280
#   vz_trim        =  0.0000
#   dx_meas        =  7.8280
# [observer]
#   dx_hat (est)   =  7.7185
#   d_hat  (est)   =  1.7218
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7059
# [mpc initial condition]
#   dX0            =  7.7185
# [mpc output]
#   du_cmd         = -14.8608
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 0.95:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.7196
#   vz_trim        =  0.0000
#   dx_meas        =  7.7196
# [observer]
#   dx_hat (est)   =  7.6103
#   d_hat  (est)   =  1.7273
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7431
# [mpc initial condition]
#   dX0            =  7.6103
# [mpc output]
#   du_cmd         = -14.8235
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.00:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.6110
#   vz_trim        =  0.0000
#   dx_meas        =  7.6110
# [observer]
#   dx_hat (est)   =  7.5020
#   d_hat  (est)   =  1.7308
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7668
# [mpc initial condition]
#   dX0            =  7.5020
# [mpc output]
#   du_cmd         = -14.7999
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.05:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.5022
#   vz_trim        =  0.0000
#   dx_meas        =  7.5022
# [observer]
#   dx_hat (est)   =  7.3934
#   d_hat  (est)   =  1.7318
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7737
# [mpc initial condition]
#   dX0            =  7.3934
# [mpc output]
#   du_cmd         = -14.7930
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.10:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.3935
#   vz_trim        =  0.0000
#   dx_meas        =  7.3935
# [observer]
#   dx_hat (est)   =  7.2847
#   d_hat  (est)   =  1.7321
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7757
# [mpc initial condition]
#   dX0            =  7.2847
# [mpc output]
#   du_cmd         = -14.7910
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.15:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.2848
#   vz_trim        =  0.0000
#   dx_meas        =  7.2848
# [observer]
#   dx_hat (est)   =  7.1760
#   d_hat  (est)   =  1.7326
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7795
# [mpc initial condition]
#   dX0            =  7.1760
# [mpc output]
#   du_cmd         = -14.7872
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.20:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.1761
#   vz_trim        =  0.0000
#   dx_meas        =  7.1761
# [observer]
#   dx_hat (est)   =  7.0674
#   d_hat  (est)   =  1.7332
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7832
# [mpc initial condition]
#   dX0            =  7.0674
# [mpc output]
#   du_cmd         = -14.7834
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.25:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  7.0674
#   vz_trim        =  0.0000
#   dx_meas        =  7.0674
# [observer]
#   dx_hat (est)   =  6.9587
#   d_hat  (est)   =  1.7334
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7849
# [mpc initial condition]
#   dX0            =  6.9587
# [mpc output]
#   du_cmd         = -14.7818
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.30:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.9587
#   vz_trim        =  0.0000
#   dx_meas        =  6.9587
# [observer]
#   dx_hat (est)   =  6.8500
#   d_hat  (est)   =  1.7335
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7850
# [mpc initial condition]
#   dX0            =  6.8500
# [mpc output]
#   du_cmd         = -14.7816
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.35:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.8500
#   vz_trim        =  0.0000
#   dx_meas        =  6.8500
# [observer]
#   dx_hat (est)   =  6.7413
#   d_hat  (est)   =  1.7335
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7854
# [mpc initial condition]
#   dX0            =  6.7413
# [mpc output]
#   du_cmd         = -14.7812
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.7413
#   vz_trim        =  0.0000
#   dx_meas        =  6.7413
# [observer]
#   dx_hat (est)   =  6.6326
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7859
# [mpc initial condition]
#   dX0            =  6.6326
# [mpc output]
#   du_cmd         = -14.7808
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.6326
#   vz_trim        =  0.0000
#   dx_meas        =  6.6326
# [observer]
#   dx_hat (est)   =  6.5239
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7860
# [mpc initial condition]
#   dX0            =  6.5239
# [mpc output]
#   du_cmd         = -14.7806
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.5239
#   vz_trim        =  0.0000
#   dx_meas        =  6.5239
# [observer]
#   dx_hat (est)   =  6.4152
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7859
# [mpc initial condition]
#   dX0            =  6.4152
# [mpc output]
#   du_cmd         = -14.7807
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.4152
#   vz_trim        =  0.0000
#   dx_meas        =  6.4152
# [observer]
#   dx_hat (est)   =  6.3065
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7861
# [mpc initial condition]
#   dX0            =  6.3065
# [mpc output]
#   du_cmd         = -14.7806
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.3065
#   vz_trim        =  0.0000
#   dx_meas        =  6.3065
# [observer]
#   dx_hat (est)   =  6.1978
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7861
# [mpc initial condition]
#   dX0            =  6.1978
# [mpc output]
#   du_cmd         = -14.7805
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.1978
#   vz_trim        =  0.0000
#   dx_meas        =  6.1978
# [observer]
#   dx_hat (est)   =  6.0891
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7861
# [mpc initial condition]
#   dX0            =  6.0891
# [mpc output]
#   du_cmd         = -14.7805
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  6.0891
#   vz_trim        =  0.0000
#   dx_meas        =  6.0891
# [observer]
#   dx_hat (est)   =  5.9804
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7862
# [mpc initial condition]
#   dX0            =  5.9804
# [mpc output]
#   du_cmd         = -14.7805
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.9804
#   vz_trim        =  0.0000
#   dx_meas        =  5.9804
# [observer]
#   dx_hat (est)   =  5.8717
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7863
# [mpc initial condition]
#   dX0            =  5.8717
# [mpc output]
#   du_cmd         = -14.7804
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.80:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.8717
#   vz_trim        =  0.0000
#   dx_meas        =  5.8717
# [observer]
#   dx_hat (est)   =  5.7630
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7862
# [mpc initial condition]
#   dX0            =  5.7630
# [mpc output]
#   du_cmd         = -14.7804
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.85:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.7630
#   vz_trim        =  0.0000
#   dx_meas        =  5.7630
# [observer]
#   dx_hat (est)   =  5.6542
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7860
# [mpc initial condition]
#   dX0            =  5.6542
# [mpc output]
#   du_cmd         = -14.7807
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.90:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.6543
#   vz_trim        =  0.0000
#   dx_meas        =  5.6543
# [observer]
#   dx_hat (est)   =  5.5456
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7862
# [mpc initial condition]
#   dX0            =  5.5456
# [mpc output]
#   du_cmd         = -14.7805
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 1.95:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.5456
#   vz_trim        =  0.0000
#   dx_meas        =  5.5456
# [observer]
#   dx_hat (est)   =  5.4369
#   d_hat  (est)   =  1.7337
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7864
# [mpc initial condition]
#   dX0            =  5.4369
# [mpc output]
#   du_cmd         = -14.7803
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.00:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.4368
#   vz_trim        =  0.0000
#   dx_meas        =  5.4368
# [observer]
#   dx_hat (est)   =  5.3281
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7862
# [mpc initial condition]
#   dX0            =  5.3281
# [mpc output]
#   du_cmd         = -14.7805
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.05:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.3282
#   vz_trim        =  0.0000
#   dx_meas        =  5.3282
# [observer]
#   dx_hat (est)   =  5.2194
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7863
# [mpc initial condition]
#   dX0            =  5.2194
# [mpc output]
#   du_cmd         = -14.7804
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.10:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.2194
#   vz_trim        =  0.0000
#   dx_meas        =  5.2194
# [observer]
#   dx_hat (est)   =  5.1107
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7859
# [mpc initial condition]
#   dX0            =  5.1107
# [mpc output]
#   du_cmd         = -14.7808
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.15:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.1107
#   vz_trim        =  0.0000
#   dx_meas        =  5.1107
# [observer]
#   dx_hat (est)   =  5.0020
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7859
# [mpc initial condition]
#   dX0            =  5.0020
# [mpc output]
#   du_cmd         = -14.7807
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.20:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  5.0020
#   vz_trim        =  0.0000
#   dx_meas        =  5.0020
# [observer]
#   dx_hat (est)   =  4.8933
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7862
# [mpc initial condition]
#   dX0            =  4.8933
# [mpc output]
#   du_cmd         = -14.7805
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.25:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.8934
#   vz_trim        =  0.0000
#   dx_meas        =  4.8934
# [observer]
#   dx_hat (est)   =  4.7847
#   d_hat  (est)   =  1.7337
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7869
# [mpc initial condition]
#   dX0            =  4.7847
# [mpc output]
#   du_cmd         = -14.7798
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.30:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.7846
#   vz_trim        =  0.0000
#   dx_meas        =  4.7846
# [observer]
#   dx_hat (est)   =  4.6759
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7862
# [mpc initial condition]
#   dX0            =  4.6759
# [mpc output]
#   du_cmd         = -14.7804
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.35:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.6759
#   vz_trim        =  0.0000
#   dx_meas        =  4.6759
# [observer]
#   dx_hat (est)   =  4.5672
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7860
# [mpc initial condition]
#   dX0            =  4.5672
# [mpc output]
#   du_cmd         = -14.7806
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.5672
#   vz_trim        =  0.0000
#   dx_meas        =  4.5672
# [observer]
#   dx_hat (est)   =  4.4585
#   d_hat  (est)   =  1.7337
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7863
# [mpc initial condition]
#   dX0            =  4.4585
# [mpc output]
#   du_cmd         = -14.7803
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.4585
#   vz_trim        =  0.0000
#   dx_meas        =  4.4585
# [observer]
#   dx_hat (est)   =  4.3498
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7861
# [mpc initial condition]
#   dX0            =  4.3498
# [mpc output]
#   du_cmd         = -14.7806
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.3498
#   vz_trim        =  0.0000
#   dx_meas        =  4.3498
# [observer]
#   dx_hat (est)   =  4.2411
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7863
# [mpc initial condition]
#   dX0            =  4.2411
# [mpc output]
#   du_cmd         = -14.7804
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.2411
#   vz_trim        =  0.0000
#   dx_meas        =  4.2411
# [observer]
#   dx_hat (est)   =  4.1324
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7862
# [mpc initial condition]
#   dX0            =  4.1324
# [mpc output]
#   du_cmd         = -14.7804
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.1324
#   vz_trim        =  0.0000
#   dx_meas        =  4.1324
# [observer]
#   dx_hat (est)   =  4.0237
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7862
# [mpc initial condition]
#   dX0            =  4.0237
# [mpc output]
#   du_cmd         = -14.7805
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  4.0237
#   vz_trim        =  0.0000
#   dx_meas        =  4.0237
# [observer]
#   dx_hat (est)   =  3.9150
#   d_hat  (est)   =  1.7337
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7865
# [mpc initial condition]
#   dX0            =  3.9150
# [mpc output]
#   du_cmd         = -14.7801
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.9150
#   vz_trim        =  0.0000
#   dx_meas        =  3.9150
# [observer]
#   dx_hat (est)   =  3.8063
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7861
# [mpc initial condition]
#   dX0            =  3.8063
# [mpc output]
#   du_cmd         = -14.7806
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.8063
#   vz_trim        =  0.0000
#   dx_meas        =  3.8063
# [observer]
#   dx_hat (est)   =  3.6976
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7863
# [mpc initial condition]
#   dX0            =  3.6976
# [mpc output]
#   du_cmd         = -14.7803
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.80:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.6976
#   vz_trim        =  0.0000
#   dx_meas        =  3.6976
# [observer]
#   dx_hat (est)   =  3.5889
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7859
# [mpc initial condition]
#   dX0            =  3.5889
# [mpc output]
#   du_cmd         = -14.7807
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.85:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.5889
#   vz_trim        =  0.0000
#   dx_meas        =  3.5889
# [observer]
#   dx_hat (est)   =  3.4802
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7858
# [mpc initial condition]
#   dX0            =  3.4802
# [mpc output]
#   du_cmd         = -14.7809
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.90:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.4802
#   vz_trim        =  0.0000
#   dx_meas        =  3.4802
# [observer]
#   dx_hat (est)   =  3.3715
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7861
# [mpc initial condition]
#   dX0            =  3.3715
# [mpc output]
#   du_cmd         = -14.7805
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 2.95:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.3715
#   vz_trim        =  0.0000
#   dx_meas        =  3.3715
# [observer]
#   dx_hat (est)   =  3.2628
#   d_hat  (est)   =  1.7337
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7866
# [mpc initial condition]
#   dX0            =  3.2628
# [mpc output]
#   du_cmd         = -14.7801
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.00:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.2628
#   vz_trim        =  0.0000
#   dx_meas        =  3.2628
# [observer]
#   dx_hat (est)   =  3.1541
#   d_hat  (est)   =  1.7337
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7864
# [mpc initial condition]
#   dX0            =  3.1541
# [mpc output]
#   du_cmd         = -14.7803
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.05:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.1541
#   vz_trim        =  0.0000
#   dx_meas        =  3.1541
# [observer]
#   dx_hat (est)   =  3.0454
#   d_hat  (est)   =  1.7336
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7860
# [mpc initial condition]
#   dX0            =  3.0454
# [mpc output]
#   du_cmd         = -14.7807
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.10:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  3.0446
#   vz_trim        =  0.0000
#   dx_meas        =  3.0446
# [observer]
#   dx_hat (est)   =  2.9359
#   d_hat  (est)   =  1.7300
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7613
# [mpc initial condition]
#   dX0            =  2.9359
# [mpc output]
#   du_cmd         = -14.8054
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.15:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.9340
#   vz_trim        =  0.0000
#   dx_meas        =  2.9340
# [observer]
#   dx_hat (est)   =  2.8251
#   d_hat  (est)   =  1.7208
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6986
# [mpc initial condition]
#   dX0            =  2.8251
# [mpc output]
#   du_cmd         = -14.8680
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.20:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.8234
#   vz_trim        =  0.0000
#   dx_meas        =  2.8234
# [observer]
#   dx_hat (est)   =  2.7140
#   d_hat  (est)   =  1.7125
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6423
# [mpc initial condition]
#   dX0            =  2.7140
# [mpc output]
#   du_cmd         = -14.9243
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.25:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.7135
#   vz_trim        =  0.0000
#   dx_meas        =  2.7135
# [observer]
#   dx_hat (est)   =  2.6037
#   d_hat  (est)   =  1.7098
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6242
# [mpc initial condition]
#   dX0            =  2.6037
# [mpc output]
#   du_cmd         = -14.9425
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.30:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.6047
#   vz_trim        =  0.0000
#   dx_meas        =  2.6047
# [observer]
#   dx_hat (est)   =  2.4948
#   d_hat  (est)   =  1.7143
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.6545
# [mpc initial condition]
#   dX0            =  2.4948
# [mpc output]
#   du_cmd         = -14.9122
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.35:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.4970
#   vz_trim        =  0.0000
#   dx_meas        =  2.4970
# [observer]
#   dx_hat (est)   =  2.3874
#   d_hat  (est)   =  1.7252
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.7289
# [mpc initial condition]
#   dX0            =  2.3874
# [mpc output]
#   du_cmd         = -14.8377
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.3907
#   vz_trim        =  0.0000
#   dx_meas        =  2.3907
# [observer]
#   dx_hat (est)   =  2.2815
#   d_hat  (est)   =  1.7411
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.8368
# [mpc initial condition]
#   dX0            =  2.2815
# [mpc output]
#   du_cmd         = -14.7299
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.2855
#   vz_trim        =  0.0000
#   dx_meas        =  2.2855
# [observer]
#   dx_hat (est)   =  2.1772
#   d_hat  (est)   =  1.7601
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -11.9660
# [mpc initial condition]
#   dX0            =  2.1772
# [mpc output]
#   du_cmd         = -14.6007
#   u_cmd (abs)    =  40.1000
# -------------------------------
#
# Simulating time 3.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.1815
#   vz_trim        =  0.0000
#   dx_meas        =  2.1815
# [observer]
#   dx_hat (est)   =  2.0741
#   d_hat  (est)   =  1.7806
#   du_prev        = -26.5667
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -12.1058
# [mpc initial condition]
#   dX0            =  2.0741
# [mpc output]
#   du_cmd         = -14.2897
#   u_cmd (abs)    =  40.2711
# -------------------------------
#
# Simulating time 3.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  2.0801
#   vz_trim        =  0.0000
#   dx_meas        =  2.0801
# [observer]
#   dx_hat (est)   =  1.9750
#   d_hat  (est)   =  1.8095
#   du_prev        = -26.3955
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -12.3017
# [mpc initial condition]
#   dX0            =  1.9750
# [mpc output]
#   du_cmd         = -13.6070
#   u_cmd (abs)    =  40.7580
# -------------------------------
#
# Simulating time 3.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.9843
#   vz_trim        =  0.0000
#   dx_meas        =  1.9843
# [observer]
#   dx_hat (est)   =  1.8842
#   d_hat  (est)   =  1.8542
#   du_prev        = -25.9087
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -12.6062
# [mpc initial condition]
#   dX0            =  1.8842
# [mpc output]
#   du_cmd         = -12.9818
#   u_cmd (abs)    =  41.0787
# -------------------------------
#
# Simulating time 3.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.8925
#   vz_trim        =  0.0000
#   dx_meas        =  1.8925
# [observer]
#   dx_hat (est)   =  1.7970
#   d_hat  (est)   =  1.8937
#   du_prev        = -25.5880
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -12.8744
# [mpc initial condition]
#   dX0            =  1.7970
# [mpc output]
#   du_cmd         = -12.3806
#   u_cmd (abs)    =  41.4116
# -------------------------------
#
# Simulating time 3.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.8046
#   vz_trim        =  0.0000
#   dx_meas        =  1.8046
# [observer]
#   dx_hat (est)   =  1.7135
#   d_hat  (est)   =  1.9300
#   du_prev        = -25.2550
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -13.1211
# [mpc initial condition]
#   dX0            =  1.7135
# [mpc output]
#   du_cmd         = -11.8054
#   u_cmd (abs)    =  41.7402
# -------------------------------
#
# Simulating time 3.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.7204
#   vz_trim        =  0.0000
#   dx_meas        =  1.7204
# [observer]
#   dx_hat (est)   =  1.6336
#   d_hat  (est)   =  1.9633
#   du_prev        = -24.9265
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -13.3477
# [mpc initial condition]
#   dX0            =  1.6336
# [mpc output]
#   du_cmd         = -11.2551
#   u_cmd (abs)    =  42.0639
# -------------------------------
#
# Simulating time 3.80:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.6400
#   vz_trim        =  0.0000
#   dx_meas        =  1.6400
# [observer]
#   dx_hat (est)   =  1.5572
#   d_hat  (est)   =  1.9940
#   du_prev        = -24.6028
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -13.5566
# [mpc initial condition]
#   dX0            =  1.5572
# [mpc output]
#   du_cmd         = -10.7289
#   u_cmd (abs)    =  42.3812
# -------------------------------
#
# Simulating time 3.85:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.5631
#   vz_trim        =  0.0000
#   dx_meas        =  1.5631
# [observer]
#   dx_hat (est)   =  1.4842
#   d_hat  (est)   =  2.0224
#   du_prev        = -24.2854
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -13.7492
# [mpc initial condition]
#   dX0            =  1.4842
# [mpc output]
#   du_cmd         = -10.2259
#   u_cmd (abs)    =  42.6915
# -------------------------------
#
# Simulating time 3.90:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.4897
#   vz_trim        =  0.0000
#   dx_meas        =  1.4897
# [observer]
#   dx_hat (est)   =  1.4145
#   d_hat  (est)   =  2.0485
#   du_prev        = -23.9751
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -13.9271
# [mpc initial condition]
#   dX0            =  1.4145
# [mpc output]
#   du_cmd         = -9.7453
#   u_cmd (abs)    =  42.9942
# -------------------------------
#
# Simulating time 3.95:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.4195
#   vz_trim        =  0.0000
#   dx_meas        =  1.4195
# [observer]
#   dx_hat (est)   =  1.3479
#   d_hat  (est)   =  2.0727
#   du_prev        = -23.6724
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.0916
# [mpc initial condition]
#   dX0            =  1.3479
# [mpc output]
#   du_cmd         = -9.2863
#   u_cmd (abs)    =  43.2888
# -------------------------------
#
# Simulating time 4.00:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.3525
#   vz_trim        =  0.0000
#   dx_meas        =  1.3525
# [observer]
#   dx_hat (est)   =  1.2842
#   d_hat  (est)   =  2.0951
#   du_prev        = -23.3779
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.2438
# [mpc initial condition]
#   dX0            =  1.2842
# [mpc output]
#   du_cmd         = -8.8479
#   u_cmd (abs)    =  43.5750
# -------------------------------
#
# Simulating time 4.05:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.2885
#   vz_trim        =  0.0000
#   dx_meas        =  1.2885
# [observer]
#   dx_hat (est)   =  1.2235
#   d_hat  (est)   =  2.1159
#   du_prev        = -23.0917
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.3849
# [mpc initial condition]
#   dX0            =  1.2235
# [mpc output]
#   du_cmd         = -8.4293
#   u_cmd (abs)    =  43.8525
# -------------------------------
#
# Simulating time 4.10:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.2275
#   vz_trim        =  0.0000
#   dx_meas        =  1.2275
# [observer]
#   dx_hat (est)   =  1.1655
#   d_hat  (est)   =  2.1351
#   du_prev        = -22.8142
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.5156
# [mpc initial condition]
#   dX0            =  1.1655
# [mpc output]
#   du_cmd         = -8.0298
#   u_cmd (abs)    =  44.1212
# -------------------------------
#
# Simulating time 4.15:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.1692
#   vz_trim        =  0.0000
#   dx_meas        =  1.1692
# [observer]
#   dx_hat (est)   =  1.1102
#   d_hat  (est)   =  2.1530
#   du_prev        = -22.5454
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.6370
# [mpc initial condition]
#   dX0            =  1.1102
# [mpc output]
#   du_cmd         = -7.6486
#   u_cmd (abs)    =  44.3810
# -------------------------------
#
# Simulating time 4.20:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.1136
#   vz_trim        =  0.0000
#   dx_meas        =  1.1136
# [observer]
#   dx_hat (est)   =  1.0574
#   d_hat  (est)   =  2.1696
#   du_prev        = -22.2856
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.7499
# [mpc initial condition]
#   dX0            =  1.0574
# [mpc output]
#   du_cmd         = -7.2849
#   u_cmd (abs)    =  44.6319
# -------------------------------
#
# Simulating time 4.25:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.0606
#   vz_trim        =  0.0000
#   dx_meas        =  1.0606
# [observer]
#   dx_hat (est)   =  1.0070
#   d_hat  (est)   =  2.1850
#   du_prev        = -22.0348
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.8550
# [mpc initial condition]
#   dX0            =  1.0070
# [mpc output]
#   du_cmd         = -6.9379
#   u_cmd (abs)    =  44.8738
# -------------------------------
#
# Simulating time 4.30:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  1.0100
#   vz_trim        =  0.0000
#   dx_meas        =  1.0100
# [observer]
#   dx_hat (est)   =  0.9590
#   d_hat  (est)   =  2.1994
#   du_prev        = -21.7929
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -14.9529
# [mpc initial condition]
#   dX0            =  0.9590
# [mpc output]
#   du_cmd         = -6.6071
#   u_cmd (abs)    =  45.1067
# -------------------------------
#
# Simulating time 4.35:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.9618
#   vz_trim        =  0.0000
#   dx_meas        =  0.9618
# [observer]
#   dx_hat (est)   =  0.9132
#   d_hat  (est)   =  2.2129
#   du_prev        = -21.5600
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -15.0444
# [mpc initial condition]
#   dX0            =  0.9132
# [mpc output]
#   du_cmd         = -6.2916
#   u_cmd (abs)    =  45.3307
# -------------------------------
#
# Simulating time 4.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.9158
#   vz_trim        =  0.0000
#   dx_meas        =  0.9158
# [observer]
#   dx_hat (est)   =  0.8695
#   d_hat  (est)   =  2.2255
#   du_prev        = -21.3360
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -15.1299
# [mpc initial condition]
#   dX0            =  0.8695
# [mpc output]
#   du_cmd         = -5.9908
#   u_cmd (abs)    =  45.5459
# -------------------------------
#
# Simulating time 4.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.8720
#   vz_trim        =  0.0000
#   dx_meas        =  0.8720
# [observer]
#   dx_hat (est)   =  0.8279
#   d_hat  (est)   =  2.2372
#   du_prev        = -21.1208
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -15.2100
# [mpc initial condition]
#   dX0            =  0.8279
# [mpc output]
#   du_cmd         = -5.7042
#   u_cmd (abs)    =  45.7525
# -------------------------------
#
# Simulating time 4.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.8302
#   vz_trim        =  0.0000
#   dx_meas        =  0.8302
# [observer]
#   dx_hat (est)   =  0.7883
#   d_hat  (est)   =  2.2483
#   du_prev        = -20.9142
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -15.2851
# [mpc initial condition]
#   dX0            =  0.7883
# [mpc output]
#   du_cmd         = -5.4310
#   u_cmd (abs)    =  45.9505
# -------------------------------
#
# Simulating time 4.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.7905
#   vz_trim        =  0.0000
#   dx_meas        =  0.7905
# [observer]
#   dx_hat (est)   =  0.7505
#   d_hat  (est)   =  2.2587
#   du_prev        = -20.7161
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -15.3557
# [mpc initial condition]
#   dX0            =  0.7505
# [mpc output]
#   du_cmd         = -5.1707
#   u_cmd (abs)    =  46.1402
# -------------------------------
#
# Simulating time 4.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.7525
#   vz_trim        =  0.0000
#   dx_meas        =  0.7525
# [observer]
#   dx_hat (est)   =  0.7145
#   d_hat  (est)   =  2.2684
#   du_prev        = -20.5264
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -15.4221
# [mpc initial condition]
#   dX0            =  0.7145
# [mpc output]
#   du_cmd         = -4.9228
#   u_cmd (abs)    =  46.3218
# -------------------------------
#
# Simulating time 4.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.7164
#   vz_trim        =  0.0000
#   dx_meas        =  0.7164
# [observer]
#   dx_hat (est)   =  0.6802
#   d_hat  (est)   =  2.2776
#   du_prev        = -20.3448
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -15.4846
# [mpc initial condition]
#   dX0            =  0.6802
# [mpc output]
#   du_cmd         = -4.6865
#   u_cmd (abs)    =  46.4955
# -------------------------------
#
# Simulating time 4.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.6820
#   vz_trim        =  0.0000
#   dx_meas        =  0.6820
# [observer]
#   dx_hat (est)   =  0.6476
#   d_hat  (est)   =  2.2863
#   du_prev        = -20.1711
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -15.5436
# [mpc initial condition]
#   dX0            =  0.6476
# [mpc output]
#   du_cmd         = -4.4615
#   u_cmd (abs)    =  46.6615
# -------------------------------
#
# Simulating time 4.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.6493
#   vz_trim        =  0.0000
#   dx_meas        =  0.6493
# [observer]
#   dx_hat (est)   =  0.6165
#   d_hat  (est)   =  2.2945
#   du_prev        = -20.0051
# [reference]
# ...
#
# Simulating time 13.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6673
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6665
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0008
#   u_cmd (abs)    =  49.9994
# -------------------------------
#
# Simulating time 13.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6673
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6665
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0008
#   u_cmd (abs)    =  49.9994
# -------------------------------
#
# Simulating time 13.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6673
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6665
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0008
#   u_cmd (abs)    =  49.9994
# -------------------------------
#
# Simulating time 13.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6672
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6665
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0007
#   u_cmd (abs)    =  49.9995
# -------------------------------
#
# Simulating time 13.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6672
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6665
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0007
#   u_cmd (abs)    =  49.9995
# -------------------------------
#
# Simulating time 13.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6672
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6665
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0006
#   u_cmd (abs)    =  49.9995
# -------------------------------
#
# Simulating time 13.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6672
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6665
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0006
#   u_cmd (abs)    =  49.9995
# -------------------------------
#
# Simulating time 13.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6671
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6665
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0006
#   u_cmd (abs)    =  49.9996
# -------------------------------
#
# Simulating time 13.80:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6671
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6665
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0006
#   u_cmd (abs)    =  49.9996
# -------------------------------
#
# Simulating time 13.85:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6671
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6665
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0005
#   u_cmd (abs)    =  49.9996
# -------------------------------
#
# Simulating time 13.90:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6671
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6665
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0005
#   u_cmd (abs)    =  49.9996
# -------------------------------
#
# Simulating time 13.95:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6670
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6665
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0005
#   u_cmd (abs)    =  49.9996
# -------------------------------
#
# Simulating time 14.00:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6670
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0005
#   u_cmd (abs)    =  49.9997
# -------------------------------
#
# Simulating time 14.05:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6670
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0004
#   u_cmd (abs)    =  49.9997
# -------------------------------
#
# Simulating time 14.10:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6670
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0004
#   u_cmd (abs)    =  49.9997
# -------------------------------
#
# Simulating time 14.15:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6670
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0004
#   u_cmd (abs)    =  49.9997
# -------------------------------
#
# Simulating time 14.20:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6670
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0004
#   u_cmd (abs)    =  49.9997
# -------------------------------
#
# Simulating time 14.25:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0001
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6669
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0001
# [mpc output]
#   du_cmd         = -0.0004
#   u_cmd (abs)    =  49.9997
# -------------------------------
#
# Simulating time 14.30:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0001
#   vz_trim        =  0.0000
#   dx_meas        =  0.0001
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6669
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0003
#   u_cmd (abs)    =  49.9997
# -------------------------------
#
# Simulating time 14.35:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6669
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0003
#   u_cmd (abs)    =  49.9998
# -------------------------------
#
# Simulating time 14.40:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6669
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0003
#   u_cmd (abs)    =  49.9998
# -------------------------------
#
# Simulating time 14.45:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6669
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0003
#   u_cmd (abs)    =  49.9998
# -------------------------------
#
# Simulating time 14.50:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6669
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0003
#   u_cmd (abs)    =  49.9998
# -------------------------------
#
# Simulating time 14.55:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6669
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0003
#   u_cmd (abs)    =  49.9998
# -------------------------------
#
# Simulating time 14.60:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6669
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0003
#   u_cmd (abs)    =  49.9998
# -------------------------------
#
# Simulating time 14.65:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6669
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0002
#   u_cmd (abs)    =  49.9998
# -------------------------------
#
# Simulating time 14.70:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6668
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0002
#   u_cmd (abs)    =  49.9998
# -------------------------------
#
# Simulating time 14.75:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6668
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0002
#   u_cmd (abs)    =  49.9998
# -------------------------------
#
# Simulating time 14.80:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6668
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0002
#   u_cmd (abs)    =  49.9998
# -------------------------------
#
# Simulating time 14.85:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6668
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0002
#   u_cmd (abs)    =  49.9999
# -------------------------------
#
# Simulating time 14.90:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6668
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0002
#   u_cmd (abs)    =  49.9999
# -------------------------------
#
# Simulating time 14.95:
# [zvel MPC step]
# [measurement]
#   vz_meas        =  0.0000
#   vz_trim        =  0.0000
#   dx_meas        =  0.0000
# [observer]
#   dx_hat (est)   =  0.0000
#   d_hat  (est)   =  2.4515
#   du_prev        = -16.6668
# [reference]
#   vz_target_abs  =  0.0000
# [steady-state target]
#   dxs (state ss) =  0.0000
#   dus (input ss) = -16.6666
# [mpc initial condition]
#   dX0            =  0.0000
# [mpc output]
#   du_cmd         = -0.0002
#   u_cmd (abs)    =  49.9999
# -------------------------------
# AppLayout(children=(HBox(children=(Play(value=0, description='Press play', max=299, step=2), IntSlider(value=0…

# %%
##################################

        # SIMU INFO

##################################
print("=== Simulation info ===")
print(f"Ts           = {Ts} s")
print(f"Horizon H    = {H} s ({int(H/Ts)} steps)")
print(f"Sim time     = {sim_time} s")
print(f"Method       = linear")
print("")



##################################

    # Input constraints INFO

##################################

print("=== Input constraints check ===")

print(f"d1   in [{np.rad2deg(u_cl[0,:].min()):.3f}, {np.rad2deg(u_cl[0,:].max()):.3f}]   (limit ±15°)")
print(f"d2   in [{np.rad2deg(u_cl[1,:].min()):.3f}, {np.rad2deg(u_cl[1,:].max()):.3f}]   (limit ±15°)")
print(f"Pavg in [{u_cl[2,:].min():.2f}, {u_cl[2,:].max():.2f}]   (limit [40,80])")
print(f"Pdif in [{u_cl[3,:].min():.2f}, {u_cl[3,:].max():.2f}]   (limit ±20)")
print("")


import numpy as np

alpha = np.rad2deg(x_cl[3, :])
beta  = np.rad2deg(x_cl[4, :])


##################################

    # Angle constraints INFO

##################################

print("=== Angle constraints check ===")
print(f"alpha max |α| = {np.abs(alpha).max():.2f} deg   (limit 10 deg)")
print(f"beta  max |β| = {np.abs(beta).max():.2f} deg   (limit 10 deg)")
print("")
# Out:
# === Simulation info ===
# Ts           = 0.05 s
# Horizon H    = 5.0 s (100 steps)
# Sim time     = 15 s
# Method       = linear
#
# === Input constraints check ===
# d1   in [-14.900, 14.900]   (limit ±15°)
# d2   in [-14.900, 14.900]   (limit ±15°)
# Pavg in [40.10, 50.00]   (limit [40,80])
# Pdif in [-0.11, 0.06]   (limit ±20)
#
# === Angle constraints check ===
# alpha max |α| = 11.96 deg   (limit 10 deg)
# beta  max |β| = 11.58 deg   (limit 10 deg)

# %%
def settling_time(t, signal, tol=0.15):
    ref = 0.0
    err = np.abs(signal - ref)
    idx = np.where(err <= tol)[0]
    if len(idx) == 0:
        return None
    for k in idx:
        if np.all(err[k:] <= tol):
            return t[k]
    return None

def print_settling(name, t, sig, tol):
    ts = settling_time(t, sig, tol)
    if ts is None:
        print(f"{name} settling time: > {t[-1]:.2f} s (not settled)")
    else:
        print(f"{name} settling time: {ts:.2f} s")

##################################

    # Settling time INFO

##################################
print("=== Settling time ===")
print_settling("vx", t_cl, x_cl[6,:], tol=0.05)
print_settling("vy", t_cl, x_cl[7,:], tol=0.05)
print_settling("vz", t_cl, x_cl[8,:], tol=0.05)
print("")

Xf_x = mpc.mpc_x.Xf  # terminal set xvel
inside = [
    Xf_x.contains(x_cl[mpc.mpc_x.x_ids, k] - mpc.mpc_x.xs)
    for k in range(x_cl.shape[1])
]

first_inside = next((t_cl[k] for k,v in enumerate(inside) if v), None)

##################################

    # Terminal set entry INFO

##################################

print("=== Terminal set entry ===")
print(f"xvel enters Xf at t = {first_inside:.2f} s")
print("")


##################################

      # Trim values INFO

##################################

print("=== TRIM VALUES ===")

print("\n--- xvel ---")
print("xs_xvel =", mpc.mpc_x.xs)
print("us_xvel =", mpc.mpc_x.us)

print("\n--- yvel ---")
print("xs_yvel =", mpc.mpc_y.xs)
print("us_yvel =", mpc.mpc_y.us)

print("\n--- zvel ---")
print("xs_zvel =", mpc.mpc_z.xs)
print("us_zvel =", mpc.mpc_z.us)

print("\n--- roll ---")
print("xs_roll =", mpc.mpc_roll.xs)
print("us_roll =", mpc.mpc_roll.us)
# Out:
# === Settling time ===
# vx settling time: 4.40 s
# vy settling time: 4.40 s
# vz settling time: 7.35 s
#
# === Terminal set entry ===
# xvel enters Xf at t = 3.10 s
#
# === TRIM VALUES ===
#
# --- xvel ---
# xs_xvel = [0. 0. 0.]
# us_xvel = [0.]
#
# --- yvel ---
# xs_yvel = [0. 0. 0.]
# us_yvel = [0.]
#
# --- zvel ---
# xs_zvel = [0.]
# us_zvel = [66.66666667]
#
# --- roll ---
# xs_roll = [0. 0.]
# us_roll = [0.]

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(t_ol[:,0], x_ol[2,:,0], '--', label="OL prediction vx")
plt.plot(t_cl, x_cl[6,:], label="CL vx")
plt.xlabel("time [s]")
plt.ylabel("vx [m/s]")
plt.legend()
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()

# OL prediction at time k=0 (reconstructed)
vx_ol = mpc.mpc_x.xs[2] + x_ol[2,:,0]
plt.plot(t_ol[:,0], vx_ol, '--', label="OL prediction vx")

# CL trajectory
plt.plot(t_cl, x_cl[6,:], label="CL vx")

plt.xlabel("time [s]")
plt.ylabel("vx [m/s]")
plt.legend()
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()

# Open-loop prediction of vx at time k=0 (FULL state index!)
plt.plot(
    t_ol[:, 0],
    x_ol[6, :, 0],     # <-- index 6 = vx
    '--',
    label="OL prediction vx"
)

# Closed-loop vx
plt.plot(
    t_cl,
    x_cl[6, :],
    label="CL vx"
)

plt.xlabel("time [s]")
plt.ylabel("vx [m/s]")
plt.legend()
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()

# Open-loop prediction of vx at time k=0 (FULL state index!)
plt.plot(
    t_ol[:, 0],
    x_ol[7, :, 0],     # <-- index 6 = vx
    '--',
    label="OL prediction vy"
)

# Closed-loop vx
plt.plot(
    t_cl,
    x_cl[7, :],
    label="CL vy"
)

plt.xlabel("time [s]")
plt.ylabel("vy [m/s]")
plt.legend()
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()

# Open-loop prediction of vx at time k=0 (FULL state index!)
plt.plot(
    t_ol[:, 0],
    x_ol[8, :, 0],     # <-- index 6 = vx
    '--',
    label="OL prediction vz"
)

# Closed-loop vx
plt.plot(
    t_cl,
    x_cl[8, :],
    label="CL vz"
)

plt.xlabel("time [s]")
plt.ylabel("vz [m/s]")
plt.legend()
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()

# Open-loop prediction of vx at time k=0 (FULL state index!)
plt.plot(
    t_ol[:, 0],
    x_ol[5, :, 0],     # <-- index 6 = vx
    '--',
    label="OL prediction roll"
)

# Closed-loop vx
plt.plot(
    t_cl,
    x_cl[5, :],
    label="CL roll"
)

plt.xlabel("time [s]")
plt.ylabel("roll [rad]")
plt.legend()
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
d_hat = np.array(mpc.mpc_z.d_hat_log)  # z-velocity MPC
t = t_cl[:len(d_hat)]

plt.figure()
plt.plot(t, d_hat, linewidth=2)
plt.xlabel("Time [s]")
plt.ylabel("Estimated disturbance $\hat d$")
plt.title("Estimated disturbance (offset-free MPC)")
plt.grid(True)
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\h'
# <>:7: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\makss\AppData\Local\Temp\ipykernel_38996\1375503577.py:7: SyntaxWarning: invalid escape sequence '\h'
#   plt.ylabel("Estimated disturbance $\hat d$")
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
